# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt

(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = x_train.astype('float32') / 255.0
x_test = x_test.astype('float32') / 255.0
x_train = x_train.reshape((x_train.shape[0], 28, 28, 1))
x_test = x_test.reshape((x_test.shape[0], 28, 28, 1))

y_train = to_categorical(y_train, 10)
y_test = to_categorical(y_test, 10)

model = Sequential([
    Conv2D(32, kernel_size=(3, 3), activation='relu', input_shape=(28, 28, 1)),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Conv2D(64, kernel_size=(3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
    Dropout(0.25),
    Flatten(),
    Dense(128, activation='relu'),
    Dropout(0.5),
    Dense(10, activation='softmax')
])

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
history = model.fit(x_train, y_train, validation_split=0.1, epochs=10, batch_size=32, verbose=2)

test_loss, test_acc = model.evaluate(x_test, y_test, verbose=2)
print(f'Test accuracy: {test_acc:.4f}')

plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(['Train', 'Validation'], loc='upper left')

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

predictions = model.predict(x_test)
predicted_labels = [tf.argmax(prediction).numpy() for prediction in predictions]

plt.figure(figsize=(10, 4))
num_images = 3
for i in range(num_images):
    plt.subplot(1, num_images, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"Predicted: {predicted_labels[i]}, True: {tf.argmax(y_test[i]).numpy()}")
    plt.axis('off')
plt.show()
# Out:
# 2025-12-01 19:23:45.423049: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-01 19:23:45.461166: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2025-12-01 19:23:46.214819: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# /home/navit/DAV_LAB/.venv/lib/python3.13/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1764597227.361288  154700 gpu_device.cc:2020] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4153 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3050 6GB Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Epoch 1/10
# 2025-12-01 19:23:48.543705: I external/local_xla/xla/service/service.cc:163] XLA service 0x7f20c0004a50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2025-12-01 19:23:48.543719: I external/local_xla/xla/service/service.cc:171]   StreamExecutor device (0): NVIDIA GeForce RTX 3050 6GB Laptop GPU, Compute Capability 8.6
# 2025-12-01 19:23:48.561713: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# 2025-12-01 19:23:48.686999: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:473] Loaded cuDNN version 91002
# 2025-12-01 19:23:48.813360: I external/local_xla/xla/service/gpu/autotuning/dot_search_space.cc:208] All configs were filtered out because none of them sufficiently match the hints. Maybe the hints set does not contain a good representative set of valid configs? Working around this by using the full hints set instead.
# 2025-12-01 19:23:49.634546: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1689', 240 bytes spill stores, 240 bytes spill loads
#
# I0000 00:00:1764597231.800257  154813 device_compiler.h:196] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 2025-12-01 19:23:56.852184: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_131', 20 bytes spill stores, 20 bytes spill loads
# 1688/1688 - 10s - 6ms/step - accuracy: 0.9167 - loss: 0.2666 - val_accuracy: 0.9835 - val_loss: 0.0550
# Epoch 2/10
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9695 - loss: 0.1006 - val_accuracy: 0.9893 - val_loss: 0.0369
# Epoch 3/10
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9758 - loss: 0.0784 - val_accuracy: 0.9910 - val_loss: 0.0324
# Epoch 4/10
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9804 - loss: 0.0667 - val_accuracy: 0.9897 - val_loss: 0.0343
# Epoch 5/10
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9818 - loss: 0.0603 - val_accuracy: 0.9915 - val_loss: 0.0300
# Epoch 6/10
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9834 - loss: 0.0539 - val_accuracy: 0.9903 - val_loss: 0.0322
# Epoch 7/10
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9856 - loss: 0.0489 - val_accuracy: 0.9920 - val_loss: 0.0296
# Epoch 8/10
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9852 - loss: 0.0461 - val_accuracy: 0.9922 - val_loss: 0.0334
# Epoch 9/10
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9859 - loss: 0.0427 - val_accuracy: 0.9913 - val_loss: 0.0311
# Epoch 10/10
# 1688/1688 - 3s - 2ms/step - accuracy: 0.9877 - loss: 0.0402 - val_accuracy: 0.9930 - val_loss: 0.0275
# 313/313 - 0s - 1ms/step - accuracy: 0.9931 - loss: 0.0214
# Test accuracy: 0.9931
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
